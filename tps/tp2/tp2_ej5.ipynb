# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal as signal
from pytc2.sistemas_lineales import bodePlot, pzmap, GroupDelay, analyze_sys

print("hola")
alfa_max = 0.4
alfa_min = 48
wp = 1
ws = 3


ee =  round((10**(alfa_max/10)-1), 3)
e = ee**0.5
print(ee)
print(e)

n = 1
for n in range(1, 10, 1):
    cheby = 10*np.log10(1+ee*(np.cosh(n*np.arccosh(3))**2))
    butter = 10*np.log10(1+ee*(ws**(2*n)))
    print("order is: ", n, "alpha para butter: ", butter, "alpha para cheby: ", cheby)
    
z, p, k = signal.cheb1ap(5, alfa_max)
print(p)
print(z)
print(k)
# Out:
# hola
# 0.096
# 0.30983866769659335
# order is:  1 alpha para butter:  2.7044590801796256 alpha para cheby:  2.7044590801796256
# order is:  2 alpha para butter:  9.432966145666548 alpha para cheby:  14.58547204196593
# order is:  3 alpha para butter:  18.511604685108846 alpha para cheby:  29.74002952559782
# order is:  4 alpha para butter:  27.99930237940807 alpha para cheby:  45.04636447323491
# order is:  5 alpha para butter:  37.535603861376615 alpha para cheby:  60.357253676680585
# order is:  6 alpha para butter:  47.07734802109669 alpha para cheby:  75.66827702160397
# order is:  7 alpha para butter:  56.619697449490985 alpha para cheby:  90.9793043153503
# order is:  8 alpha para butter:  66.16211413646964 alpha para cheby:  106.29033172533917
# order is:  9 alpha para butter:  75.70453829670471 alpha para cheby:  121.60135913874993
# [-0.11932228+1.01949544j -0.31238979+0.63008283j -0.38613502-0.j
#  -0.31238979-0.63008283j -0.11932228-1.01949544j]
# []
# 0.20121735222648754

# %%
np.abs(p)
# Out:
# array([1.02645446, 0.70327218, 0.38613502, 0.70327218, 1.02645446])

# %%
num, den = signal.zpk2tf(z,p,k)

# %%
from scipy.signal import TransferFunction
analyze_sys(TransferFunction(num, den))

# %%
pzmap(TransferFunction(num, den))
# Out:
# (1, <Axes: xlabel='$\\sigma$', ylabel='j$\\omega$'>)
