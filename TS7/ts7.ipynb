# %% [markdown]
# #### Teoría de Circuitos II
#
# #  Tarea Semanal 7
#
# #### Autor: Federico Rodriguez Vizzon
# <img src="./assets/ned.jpeg" align="left" width="150" />

# %% [markdown]
# # Parte 1
# ## Calcular los parametros Z de la siguiente red
#
# <img src="./assets/parte_1.png" align="center"/>
#
# En primer lugar recordamos como se compone la matrix Z de una red:
#
# $\begin{equation}
# \begin{vmatrix}
# V_1\\
# V_2\\
# \end{vmatrix}
# =
# \begin{vmatrix}
# Z_{11} & Z_{12}\\
# Z_{21} & Z_{22}\\
# \end{vmatrix}
# \begin{vmatrix}
# I_1\\
# I_2\\
# \end{vmatrix}
# \end{equation}$
#
# Operando y dejando a circuito abierto la salida o la entrada segun corresponda llegamos a:
#
# $Z_{11} = \frac{V_1}{I_1} \land I_2 = 0 $
#
# $Z_{12} = \frac{V_1}{I_2} \land I_1 = 0 $
#
# $Z_{21} = \frac{V_2}{I_1} \land I_2 = 0 $
#
# $Z_{22} = \frac{V_2}{I_2} \land I_2 = 0 $
#
# Nombramos a la corriente que entra por el primario del transformador como $I_{L1}$ y a la que sale por el secundario del transformador $I_{L2}$.
# Como la relacion del transformador es 1:1 (con acoplamiento ideal) y la disposicion de los bornes homologos hace que la corriente que entra por el borne superior del primario salga por el borne superior del secundario podemos decir que:
# $I_{L1} = I_{L2} = I_L$
#
# Ahora planteamos las ecuaciones del circuito:
#
# $V_1 = -V_2$
#
# $I_1 = I_{R_1} + I_{R_2} + I_L = \frac{V_1}{R_1} + \frac{V_1 - V_2}{R_2} + I_L$
#
# $I_2 = I_{R_3} + I_{R_2} + I_L = \frac{V_2}{R_3} + \frac{V_2 - V_1}{R_2} + I_L = \frac{V_2}{R_3} - \frac{V_1 - V_2}{R_2} + I_L$
#
# ### Calculo de $Z_{11}$
#
# $Z_{11} = \frac{V_1}{I_1} \land I_2 = 0 $
#
# $I_2 = \frac{V_2}{R_3} - \frac{V_1 - V_2}{R_2} + I_L = 0 \implies I_L = \frac{V_1 - V_2}{R_2} - \frac{V_2}{R_3}$
#
# $I_1 = \frac{V_1}{R_1} + \frac{V_1 - V_2}{R_2} + I_L = \frac{V_1}{R_1} + \frac{V_1 - V_2}{R_2} + \frac{V_1 - V_2}{R_2} - \frac{V_2}{R_3} = \frac{V_1}{R_1} + \frac{V_1 + V_1}{R_2} + \frac{V_1 + V_1}{R_2} + \frac{V_1}{R_3} = \frac{V_1}{R_1} + \frac{4V_1}{R_2} + \frac{V_1}{R_3} = V_1 \left(\frac{1}{R_1} + \frac{4}{R_2} + \frac{1}{R_3}\right)$
#
# $I_1 = V_1 \left(\frac{1}{R_1} + \frac{4}{R_2} + \frac{1}{R_3}\right)$
#
# Reemplazando $R_1 = 1 , R_2 = 2 , R_3 = 3 $
#
# $I_1 = V_1 \left(\frac{1}{1} + \frac{4}{2} + \frac{1}{3}\right) = V_1 \left(3 + \frac{1}{3}\right) = V_1 \left(\frac{10}{3}\right) \implies \frac{V_1}{I_1} = \frac{3}{10} = 0.3 = Z_{11}$
#
# ### Calculo de $Z_{12}$
#
# $Z_{12} = \frac{V_1}{I_2} \land I_1 = 0 $
#
# $I_1 = 0 = \frac{V_1}{R_1} + \frac{V_1 - V_2}{R_2} + I_L \implies I_L = -\frac{V_1}{R_1} - \frac{V_1 - V_2}{R_2}$
#
# $I_2 = \frac{V_2}{R_3} - \frac{V_1 - V_2}{R_2} -\frac{V_1}{R_1} - \frac{V_1 - V_2}{R_2} = -\frac{V_1}{R_3} - \frac{2V_1}{R_2} -\frac{V_1}{R_1} - \frac{2V_1}{R_2} = -\frac{V_1}{R_3} - \frac{4V_1}{R_2} -\frac{V_1}{R_1}$
#
# Agrupando y reemplazando los valores de los componentes
#
# $I_2 = -V_1 \left(\frac{1}{3} + \frac{4}{2} + 1\right) = -V_1 \left(\frac{10}{3}\right) \implies \frac{V_1}{I_1} = -\frac{3}{10} = Z_{12}$
#
# ### Calculo de $Z_{21}$
#
# $Z_{21} = \frac{V_2}{I_1} \land I_2 = 0 $
#
# $I_2 = \frac{V_2}{R_3} - \frac{V_1 - V_2}{R_2} + I_L = 0 \implies I_L = \frac{V_1 - V_2}{R_2} - \frac{V_2}{R_3}$
#
# $I_1 = \frac{V_1}{R_1} + \frac{V_1 - V_2}{R_2} + I_L = \frac{V_1}{R_1} + \frac{V_1 - V_2}{R_2} + \frac{V_1 - V_2}{R_2} - \frac{V_2}{R_3} = -\frac{V_2}{R_1} - \frac{2V_2}{R_2} - \frac{2 V_2}{R_2} - \frac{V_2}{R_3} = -V_2 \left(\frac{1}{R_1} - \frac{4}{R_2} - \frac{1}{R_3}\right)$
#
# Reemplazando los valores de los componentes
#
# $I_1 = -V_2 \left(1 - \frac{4}{2} - \frac{1}{3}\right) = -V_1 \left(\frac{10}{3}\right) \implies \frac{V_2}{I_1} = -\frac{3}{10} = -0.3 = Z_{21}$
#
# ### Calculo de $Z_{22}$
#
# $Z_{22} = \frac{V_2}{I_2} \land I_1 = 0 $
#
# $I_1 = 0 = \frac{V_1}{R_1} + \frac{V_1 - V_2}{R_2} + I_L \implies I_L = - \frac{V_1}{R_1} - \frac{V_1 - V_2}{R_2}$
#
# $I_2 = \frac{V_2}{R_3} - \frac{V_1 - V_2}{R_2} - \frac{V_1}{R_1} - \frac{V_1 - V_2}{R_2} = \frac{V_2}{R_3} + \frac{2V_2}{R_2} + \frac{V_2}{R_1} + \frac{2 V_2}{R_2} = V_2 \left(\frac{1}{R_3} + \frac{4}{R_2} + \frac{1}{R_1}\right) $
#
# Reemplazando los valores de los componentes
#
# $I_2 = V_2 \left(\frac{1}{3} + \frac{4}{2} + 1\right) = V_2\frac{10}{3} \implies \frac{V_2}{I_2} = \frac{3}{10} = 0.3 = Z_{22}$
#
# ### Matriz $Z$ de la red
#
# $\begin{equation}
# \begin{vmatrix}
# V_1\\
# V_2\\
# \end{vmatrix}
# =
# \begin{vmatrix}
# 0.3  & -0.3\\
# -0.3 & 0.3\\
# \end{vmatrix}
# \begin{vmatrix}
# I_1\\
# I_2\\
# \end{vmatrix}
# \end{equation}$
#
# ## Verificacion con Spice
#
# ### Verificacion de $Z_{11}$ y $Z_{21}$
#
# <img src="./assets/trafo_sim_i1_sch.png" align="center"/>
#
# <img src="./assets/spice_Z_11.png" align="center"/>
#
# <img src="./assets/spice_Z_21.png" align="center"/>
#
# Podemos ver que tanto el modulo como la fase conside con lo calculado.
#
# ### Verificacion de $Z_{12}$ y $Z_{22}$
#
# <img src="./assets/trafo_sim_i2_sch.png" align="center"/>
#
# <img src="./assets/spice_Z_12.png" align="center"/>
#
# <img src="./assets/spice_Z_22.png" align="center"/>
#
# Podemos ver que tanto el modulo como la fase conside con lo calculado.

# %% [markdown]
# #### Parte 2
#
# ## Calculo de la funcion transferencia por interconeccion de cuadripolos.
#
# <img src="./assets/parte_2.png" align="center"/>
#
# Observando la red vemos que la misma se conforma por 4 cuadripolos elementales conectados en cascada, a los cuales designamos como $T_1, T_2, T_3 y T_4$
#
# <img src="./assets/cascada_1.png" align="center"/>
#
# ### Matriz T de cuadripolos elementales
#
# #### Impedancia en serie
#
# <img src="./assets/elemental_z.png" align="center"/>
#
# $\begin{equation}
# \begin{vmatrix}
# V_1\\
# I_1\\
# \end{vmatrix}
# =
# \begin{vmatrix}
# 1 & Z\\
# 0 & 1\\
# \end{vmatrix}
# \begin{vmatrix}
# V_2\\
# I_2\\
# \end{vmatrix}
# \end{equation}$
#
# #### Admitancia en derivacion
#
# <img src="./assets/elemental_y.png" align="center"/>
#
# $\begin{equation}
# \begin{vmatrix}
# V_1\\
# I_1\\
# \end{vmatrix}
# =
# \begin{vmatrix}
# 1 & 0\\
# Y & 1\\
# \end{vmatrix}
# \begin{vmatrix}
# V_2\\
# I_2\\
# \end{vmatrix}
# \end{equation}$
#
# ### Obtencion de matrices
#
# $T_1 = \begin{vmatrix}
# 1 & s\frac{3}{2}\\
# 0 & 1\\
# \end{vmatrix}$
#
# $T_2 = \begin{vmatrix}
# 1 & 0\\
# s\frac{4}{3} & 1\\
# \end{vmatrix}$
#
# $T_3 = \begin{vmatrix}
# 1 & s\frac{1}{2}\\
# 0 & 1\\
# \end{vmatrix}$
#
# $T_4 = \begin{vmatrix}
# 1 & 0\\
# 1 & 1\\
# \end{vmatrix}$
#
# $T_1 \times T_2 = T_{12}=  \begin{vmatrix}
# 1 + 2s^2 & s\frac{3}{2}\\
# s\frac{4}{3} & 1\\
# \end{vmatrix}$
#
# $T_{12} \times T_3 = T_{123} = \begin{vmatrix}
# 1 + 2s^2 & s^3 + 2s\\
# s\frac{4}{3} & \frac{4s^2+6}{6}\\
# \end{vmatrix}$
#
# $T_{123} \times T_4 = T_{1234} = T = \begin{vmatrix}
# s^3 + 2s^2 + 2s + 1 & s^2 +2s\\
# s\frac{4}{3} + \frac{4s^2+6}{6} & \frac{4s^2+6}{6}\\
# \end{vmatrix}$
#
# Recordando que $A = \frac{V_1}{V_2} \implies \frac{V_2}{V_1} = \frac{1}{A} = \frac{1}{s^3 + 2s^2 + 2s + 1}$
#
# De lo aprendido en el primer cuatrimestre sabemos que es un filtro pasabajos del tipo Butterworth, en la simulacion deberiamos corroborar esta declaracion.
#
# ### Simulacion con spice
#
# <img src="./assets/butter_sch.png" align="center"/>
#
# <img src="./assets/butter_ac_plot.png" align="center"/>
#
# En los graficos de la simulacion podemos validar que se trata de un filtro pasabajos de orden 3.
# La pendiente de la respuesta de modulo es $60\frac{dB}{dec}$
#
# ## Conformacion MAI de la red
#
# Redibujamos el circuito de la siguiente forma y enumeramos los nodos.
#
# <img src="./assets/mai_circuit.jpg" align="center"/>
#
# Donde:
#
# $Y_a = \frac{2}{3s}$
#
# $Y_b = \frac{2}{s}$
#
# $Y_c = \frac{4s}{3}$
#
# $G = 1$
#
# $
# MAI =
# \begin{vmatrix}
# Y_a & -Y_a & 0 & 0\\
# -Y_a & Y_a + Y_b + Y_c & -Y_b & -Y_c\\
# 0 & -Y_b & G + Y_b & -G \\
# 0 & -Y_c & -G & G + Y_c
# \end{vmatrix}
# =
# \begin{vmatrix}
# \frac{2}{3s} & -\frac{2}{3s} & 0 & 0\\
# -\frac{2}{3s} & \frac{2}{3s} + \frac{2}{s} + \frac{4s}{3} & -\frac{2}{s} & -\frac{4s}{3}\\
# 0 & -\frac{2}{s} & 1 + \frac{2}{s} & -1 \\
# 0 & -\frac{4s}{3} & -1 & 1 + \frac{4s}{3}
# \end{vmatrix} =
# \begin{vmatrix}
# \frac{2}{3s} & -\frac{2}{3s} & 0 & 0\\
# -\frac{2}{3s} & \frac{4s^2+8}{3s} & -\frac{2}{s} & -\frac{4s}{3}\\
# 0 & -\frac{2}{s} & \frac{s + 2}{s} & -1 \\
# 0 & -\frac{4s}{3} & -1 & \frac{4s + 3}{3}
# \end{vmatrix}$
#
# La suma de todos los elementos en una columna o una fila da 0.
#
# La fila 1 es igual a la colummna 1, la fila 2 con la columna 2 y asi todas las demas.
#
# Dicho esto podemos decir que la MAI esta correctamente conformada.
#
# ## Calculo de la transferencia $\frac{V_2}{V_1}$ por MAI
#
# $V^{ij}_{mn} = \frac{V_{ij}}{V_{mn}} = sgn(i-j)sgn(m-n) \frac{\underline{Y}^{ij}_{mn}}{\underline{Y}^{mn}_{mn}}$
#
# $\underline{Y}^{ij}_{mn} = (-1)^{m+n+i+j}\Delta Y^{ij}_{mn}$
#
# $\Delta Y^{ij}_{mn}$ es el determinante de la MAI con las columnas i,j suprimidas y las filas m,n suprimidas.
#
# $V^{34}_{14} = \frac{V_{34}}{V_{14}} = (-1)(-1)\frac{\underline{Y}^{34}_{14}}{\underline{Y}^{14}_{14}}$
#
# $\underline{Y}^{14}_{14} = (-1)^{1+4+1+4} \times\left( \frac{4s^2+8}{3s}\frac{s+2}{s} - \frac{4}{s^2}\right) =
# \frac{4s^3 + 8s^2 + 8s + 16}{3s^2} - \frac{4}{s^2} = \frac{4s^3 + 8s^2 + 8s + 16 - 12}{3s^2} = \frac{4s^3 + 8s^2 + 8s + 4}{3s^2}$
#
# $\underline{Y}^{14}_{34} = (-1)^{1+4+3+4} \times \left(\frac{-2}{3s}\frac{-2}{s}\right) = \frac{4}{3s^3}$
#
# $\frac{V_2}{V_1} = \frac{V_{34}}{V_{14}} = \frac{4}{3s^3} \times \frac{3s^2}{4s^3 + 8s^2 + 8s + 4} =
#  \frac{4}{3s^3} \times \frac{3s^2}{4}\frac{1}{s^3 + 2s^2 + 2s + 1} = \frac{1}{s^3 + 2s^2 + 2s + 1} = \frac{V_2}{V_1}$
#
# Se observa que lo obtenido por interconeccion de cuadripolos y lo obtenido por el metodo de MAI es consistente.
#
# ### Calculo de la Admitancia de entrada por MAI
#
# $Z^{ij}_{mn} = \frac{V_{ij}}{I_{mn}} = sgn(i-j)sgn(m-n)\frac{\underline{Y}^{ij}_{mn}}{\underline{Y}^{n}_{n}}$
#
# $\underline{Y}^i_j = (-1)^{i+j}\Delta Y^i_j$
#
# $\Delta Y^i_j$ es el determinate de la mai con la fila i y la columna j suprimidas.
#
# $Z_1 = Z^{14}_{14} = \frac{V_{14}}{I_{14}} = (-1)(-1)\frac{\underline{Y}^{14}_{14}}{\underline{Y}^{4}_{4}}$
#
# $\underline{Y}^{14}_{14} =  \frac{4s^3 + 8s^2 + 8s + 4}{3s^2}$ (se calculo en el punto anterior)
#
# $\underline{Y}^{4}_{4} = (-1)^{4+4} \times \Delta{\begin{vmatrix}
# \frac{2}{3s} & -\frac{2}{3s} & 0 \\
# -\frac{2}{3s} & \frac{4s^2+8}{3s} & -\frac{2}{s}\\
# 0 & -\frac{2}{s} & \frac{s + 2}{s}
# \end{vmatrix}} = \frac{2}{3s}\left( \frac{4s^2+8}{3s}\frac{s+2}{s} - \frac{4}{s^2}\right) -\frac{-2}{3s}\left(\frac{-2}{3s}\frac{s+2}{s}\right) + 0 = \frac{2}{3s} \left( \frac{4s^3+ 8s^2 + 8s + 4}{3s^2} - \frac{2s+4}{3s^2}\right)= \frac{2}{3s}\left(\frac{4s^3+8s^2+8s+4-2s-4}{2s^2}\right) = \frac{2}{3s}\frac{4s^3+8s^2+6s}{3s^2} = \frac{2}{3}\frac{4s^2+8s+6}{3s^2}$
#
# $Z_1 = Z^{14}_{14} = \frac{4s^3 + 8s^2 + 8s + 4}{3s^2} \frac{3s^2}{4s^2+8s+6} \frac{3}{2} = \frac{3}{2}\frac{4s^3 + 8s^2 + 8s + 4}{4s^2+8s+6} = \frac{3}{2}\frac{s^3+2s^2+2s+1}{s^2+2s+\frac{3}{2}}$
#
# $Y_1 = \frac{1}{Z_1} = \frac{2}{3}\frac{s^2+2s+\frac{3}{2}}{s^3+2s^2+2s+1}$
